# %% [markdown]
# Loading the Libraries

# %%
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
scipy.__version__
# Out:
# '1.16.3'

# %%
ekg=scipy.datasets.electrocardiogram()

# %%
ekg
# Out:
# array([-0.245, -0.215, -0.185, ..., -0.405, -0.395, -0.385])

# %%
ekg=pd.Series(ekg)

# %%
ekg
# Out:
# 0        -0.245
# 1        -0.215
# 2        -0.185
# 3        -0.175
# 4        -0.170
#           ...
# 107995   -0.440
# 107996   -0.440
# 107997   -0.405
# 107998   -0.395
# 107999   -0.385
# Length: 108000, dtype: float64

# %%
ekg.plot()
# Out:
# <Axes: >

# %%
ekg[:1000].plot()
# Out:
# <Axes: >

# %%
ekg[:1000].plot()
plt.title("3 seconds of EKG Data")
# Out:
# Text(0.5, 1.0, '3 seconds of EKG Data')

# %%
r_waves, metadata=scipy.signal.find_peaks(ekg[:1000], height=1.0)

# %%
r_waves,metadata =scipy.signal.find_peaks(ekg[:1000], height=1.0)

# %%
r_waves
# Out:
# array([125, 343, 552, 748, 944])

# %%
ekg[:1000].plot()
plt.plot(r_waves, ekg[:1000][r_waves])

# %%
three_second_ekg=ekg[:1000]
ekg[:1000].plot()
plt.plot(r_waves, three_second_ekg[r_waves], "x")
plt.title("Three seconds EKG with labeled R waves")
# Out:
# Text(0.5, 1.0, 'Three seconds EKG with labeled R waves')
